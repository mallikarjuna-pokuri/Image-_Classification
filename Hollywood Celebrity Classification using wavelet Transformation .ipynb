# %%
import numpy as np
import cv2
import matplotlib
from matplotlib import pyplot as plt
import os 
import random

# %% [markdown]
# **Using CV2 cascades to find face and eyes from the images**

# %%
eyes_cascade_path = os.path.abspath('haarcascade_eye.xml')
face_cascade_path = os.path.abspath('haarcascade_frontalface_default.xml')

# %%
eye_cascade = cv2.CascadeClassifier(eyes_cascade_path)
face_cascade = cv2.CascadeClassifier(face_cascade_path)

# %%
labels = ['Christian Bale','Johnny Depp','Leonardo Dicaprio','Matt Damon']
files_names = []
for label in labels:
    file_path = os.path.join('./'+label)
    for img in os.listdir(file_path):
        if img[-4:]!='.jpg':
            os.remove(os.path.join(file_path,img))
        else:
            files_names.append(os.path.join(file_path,img))

# %%
files_names
# Out:
# ['./Christian Bale\\1200px-Christian_Bale_2009.jpg',
#  './Christian Bale\\12441_v9_bb.jpg',
#  './Christian Bale\\16525779265472.jpg',
#  './Christian Bale\\1C5696424-120909-christian-bale.jpg',
#  './Christian Bale\\20120721__20120722_A26_ND22MOVIESp1.jpg',
#  './Christian Bale\\220707174235-christian-bale-file-062322.jpg',
#  './Christian Bale\\230228102741-01b-christian-bale-makeup-90s-restricted.jpg',
#  './Christian Bale\\2K20AH6.jpg',
#  './Christian Bale\\459896580.jpg',
#  './Christian Bale\\558678178049.jpg',
#  './Christian Bale\\6-Christian-Bale.jpg',
#  './Christian Bale\\7ea3851c2c9966507654fb44df605acc-1200-80.jpg',
#  './Christian Bale\\81mLGs6phBS._AC_UF10001000_QL80_.jpg',
#  './Christian Bale\\AcfW3p5D6ov573fABLyGqwYdolD.jpg',
#  './Christian Bale\\AGvuzYbytZ8hA1JgaVUP1_bnYkfiRoYRTdgVGbuht_8s64-c-mo.jpg',
#  './Christian Bale\\american-psycho-christian-bale-tom-cruise.jpg',
#  './Christian Bale\\bale-wallstpsychos.jpg',
#  './Christian Bale\\Bale.jpg',
#  './Christian Bale\\BALEBATMANBUSTMAIN_2000x.jpg',
#  './Christian Bale\\BN-FX013_Mag121_PP_20141205152410.jpg',
#  './Christian Bale\\cf1286c090607316394cebe6c9329b72cf-christian-bale.1x.rsquare.w1400.jpg',
#  './Christian Bale\\christian-bale-01-gty-iwb-220628_1656428735439_hpMain_16x9_608.jpg',
#  './Christian Bale\\christian-bale-1280jpg-3885a3_160w.jpg',
#  './Christian Bale\\christian-bale-1656502852.jpg',
#  './Christian Bale\\Christian-Bale-and-Robert-Pattinson-1.jpg',
#  './Christian Bale\\christian-bale-batman-99.jpg',
#  './Christian Bale\\christian-bale-batman-flash-movie.jpg',
#  './Christian Bale\\christian-bale-chris-rock.jpg',
#  './Christian Bale\\Christian-Bale-Dark-Knight-584cc7f-scaled.jpg',
#  './Christian Bale\\christian-bale-horror-movie-550x309.jpg',
#  './Christian Bale\\christian-bale-jobs.jpg',
#  './Christian Bale\\christian-bale-kids.jpg',
#  './Christian Bale\\christian-bale-main-4.jpg',
#  './Christian Bale\\Christian-Bale-new-movie-after-The-Pale-Blue-Eye-Everything-we-know-so-far-scaled-e1672302777507.jpg',
#  './Christian Bale\\Christian-Bale-Pale-Blue-Eye-Premiere-GettyImages-1449315110-H-2023.jpg',
#  './Christian Bale\\Christian-Bale-Patrick-Bateman-American-Psycho.jpg',
#  './Christian Bale\\Christian-Bale-Thanks-Leonardo-DiCaprio.jpg',
#  './Christian Bale\\christian-bale-thor-rumors.jpg',
#  './Christian Bale\\Christian-Bale-Welsh.jpg',
#  './Christian Bale\\Christian-Bale.jpg',
#  './Christian Bale\\christian-bale3.jpg',
#  './Christian Bale\\Christian-Bale4.jpg',
#  './Christian Bale\\Christian-Bale5.jpg',
#  './Christian Bale\\Christian-Bale6.jpg',
#  './Christian Bale\\Christian-Bale7.jpg',
#  './Christian Bale\\Christian-Bale_GettyImages-504405052.jpg',
#  './Christian Bale\\Christian_Bale-7837.jpg',
#  './Christian Bale\\christian_bale.jpg',
#  './Christian Bale\\christian_bale_dark_knight.jpg',
#  './Christian Bale\\Christian_Bale_Mug_2.jpg',
#  './Christian Bale\\Collage20Maker-26-Jul-2023-01-59-PM-2366.jpg',
#  './Christian Bale\\Culture_ChristianBale_Thor-1185569988.jpg',
#  './Christian Bale\\e15de85060a443dbce29f7eedffa8eddc6-christian-bale-2.jpg',
#  './Christian Bale\\f6f88927ff57f6ae30b0d8be61b0281c56-christian-bale-ranking.jpg',
#  './Christian Bale\\featured49.jpg',
#  './Christian Bale\\gettyimages-1185569988_copy.jpg',
#  './Christian Bale\\GettyImages-1425962190-e1664987389989.jpg',
#  './Christian Bale\\GettyImages-1426000083-H-2022.jpg',
#  './Christian Bale\\GettyImages-1426021969-1.jpg',
#  './Christian Bale\\GettyImages-1426024131.jpg',
#  './Christian Bale\\Getty_ChristianBale.jpg',
#  './Christian Bale\\GQ1122_Bale_09.jpg',
#  './Christian Bale\\image-w856.jpg',
#  './Christian Bale\\image33.jpg',
#  './Christian Bale\\image34.jpg',
#  './Christian Bale\\images.jpg',
#  './Christian Bale\\images10.jpg',
#  './Christian Bale\\images11.jpg',
#  './Christian Bale\\images12.jpg',
#  './Christian Bale\\images13.jpg',
#  './Christian Bale\\images14.jpg',
#  './Christian Bale\\images15.jpg',
#  './Christian Bale\\images16.jpg',
#  './Christian Bale\\images17.jpg',
#  './Christian Bale\\images18.jpg',
#  './Christian Bale\\images19.jpg',
#  './Christian Bale\\images2.jpg',
#  './Christian Bale\\images20.jpg',
#  './Christian Bale\\images21.jpg',
#  './Christian Bale\\images22.jpg',
#  './Christian Bale\\images23.jpg',
#  './Christian Bale\\images24.jpg',
#  './Christian Bale\\images25.jpg',
#  './Christian Bale\\images26.jpg',
#  './Christian Bale\\images27.jpg',
#  './Christian Bale\\images28.jpg',
#  './Christian Bale\\images29.jpg',
#  './Christian Bale\\images3.jpg',
#  './Christian Bale\\images30.jpg',
#  './Christian Bale\\images31.jpg',
#  './Christian Bale\\images32.jpg',
#  './Christian Bale\\images33.jpg',
#  './Christian Bale\\images34.jpg',
#  './Christian Bale\\images35.jpg',
#  './Christian Bale\\images36.jpg',
#  './Christian Bale\\images37.jpg',
#  './Christian Bale\\images38.jpg',
#  './Christian Bale\\images39.jpg',
#  './Christian Bale\\images4.jpg',
#  './Christian Bale\\images40.jpg',
#  './Christian Bale\\images41.jpg',
#  './Christian Bale\\images42.jpg',
#  './Christian Bale\\images43.jpg',
#  './Christian Bale\\images44.jpg',
#  './Christian Bale\\images5.jpg',
#  './Christian Bale\\images6.jpg',
#  './Christian Bale\\images7.jpg',
#  './Christian Bale\\images8.jpg',
#  './Christian Bale\\images9.jpg',
#  './Christian Bale\\intro-1664836965.jpg',
#  './Christian Bale\\intro-1688041156.jpg',
#  './Christian Bale\\Is-Christian-Bales-Batman-in-the-Flash-Heres-What-We-Know.jpg',
#  './Christian Bale\\maxresdefault.jpg',
#  './Christian Bale\\maxresdefault2.jpg',
#  './Christian Bale\\MCDDAKN_EC004.jpg',
#  './Christian Bale\\MCDDAKN_EC081.jpg',
#  './Christian Bale\\MV5BMTkxMzk4MjQ4MF5BMl5BanBnXkFtZTcwMzExODQxOA._V1_FMjpg_UX1000_.jpg',
#  './Christian Bale\\MV5BZDg2YThlMTItYzhhMy00OWE3LTljYTAtYTExMDM5NzRjOGFhXkEyXkFqcGdeQXVyMTEzMTI1Mjk3._V1_.jpg',
#  './Christian Bale\\ps-Ex-Winona-Ryder-Without-Whom-He-Would-Have-Never-Met-His-Wife-Sibi-Blazic.jpg',
#  './Christian Bale\\Qh4sygXgt5_mXFUFu7kdP9-D6fGQQnaTj2Q1ihxL6VZ5TXCMP3ZsH54xOjWSJwwuQYYPUoytP4YP.jpg',
#  './Christian Bale\\rs_1200x1200-221006044644-1200-Christian-Bale-Leonardo-Dicaprio-KD-100622.jpg',
#  './Christian Bale\\The-Dark-Knight-4-How-Christian-Bales-Batman-Can-Return-.jpg',
#  './Christian Bale\\thor-feature.jpg',
#  './Johnny Depp\\-gun-at-a-9-year-old-girl-for-bringing-real-tears-slammed-directors-strategy.jpg',
#  './Johnny Depp\\0_DNP_CHP_290723Slug_10574-D.jpg',
#  './Johnny Depp\\100328682.jpg',
#  './Johnny Depp\\107-Johnny-Depp.jpg',
#  './Johnny Depp\\16839797234679.jpg',
#  './Johnny Depp\\16848999779862.jpg',
#  './Johnny Depp\\1686214317_johnny-depp.jpg',
#  './Johnny Depp\\16871019984068.jpg',
#  './Johnny Depp\\170px-Johnny_Depp_28July_200929_2.jpg',
#  './Johnny Depp\\17cannes-depp-wmqh-mediumSquareAt3X.jpg',
#  './Johnny Depp\\304b46e62f93-gettyimages-1338541458.jpg',
#  './Johnny Depp\\321a6f7ded9c4795a55f24effa5dcb42.jpg',
#  './Johnny Depp\\33623_v9_bd.jpg',
#  './Johnny Depp\\3pclqrj8_johnny-depp_625x300_16_May_23.jpg',
#  './Leonardo Dicaprio\\images.jpg',
#  './Leonardo Dicaprio\\images10.jpg',
#  './Leonardo Dicaprio\\images11.jpg',
#  './Leonardo Dicaprio\\images12.jpg',
#  './Leonardo Dicaprio\\images13.jpg',
#  './Leonardo Dicaprio\\images14.jpg',
#  './Leonardo Dicaprio\\images15.jpg',
#  './Leonardo Dicaprio\\images16.jpg',
#  './Leonardo Dicaprio\\images17.jpg',
#  './Leonardo Dicaprio\\images18.jpg',
#  './Leonardo Dicaprio\\images2.jpg',
#  './Leonardo Dicaprio\\images3.jpg',
#  './Leonardo Dicaprio\\images4.jpg',
#  './Leonardo Dicaprio\\images5.jpg',
#  './Leonardo Dicaprio\\images6.jpg',
#  './Leonardo Dicaprio\\images7.jpg',
#  './Leonardo Dicaprio\\images8.jpg',
#  './Leonardo Dicaprio\\images9.jpg',
#  './Leonardo Dicaprio\\james-cameron-revealed-leonardo-dicaprio-almost-l-2-2768-1669217527-10_dblbig.jpg',
#  './Leonardo Dicaprio\\james-dean-leonardo-dicaprio.jpg',
#  './Leonardo Dicaprio\\Kate-Winslet-Leonardo-DiCaprio-posing-in-front-of-TItanic-and-Revolutionary-Road.jpg',
#  './Leonardo Dicaprio\\land-star-arabella-chi-enjoy-a-sunny-getaway-to-ibiza-along-with-friends-001.jpg',
#  './Leonardo Dicaprio\\Leionardo2520DiCaprio2520Gigi2520Hadid.jpg',
#  './Leonardo Dicaprio\\leo-dicaprio-gfs.jpg',
#  './Leonardo Dicaprio\\leo-dicaprio-tux.jpg',
#  './Leonardo Dicaprio\\leo.jpg',
#  './Leonardo Dicaprio\\Leonardo-di-Caprio-1997_film.jpg',
#  './Leonardo Dicaprio\\Leonardo-Dicaprio-1024x1024.jpg',
#  './Leonardo Dicaprio\\Leonardo-DiCaprio-Camilla-Morrone-August-31-2022.jpg',
#  './Leonardo Dicaprio\\leonardo-dicaprio-environment-birthday-update-HEADER.jpg',
#  './Leonardo Dicaprio\\Leonardo-DiCaprio-Home-Was-Decorated-With-Titanic-Items-Promo.jpg',
#  './Leonardo Dicaprio\\Leonardo-DiCaprio-James-Dean.jpg',
#  './Leonardo Dicaprio\\leonardo-dicaprio-jan-1998-annie-leibovitz.jpg',
#  './Leonardo Dicaprio\\Leonardo-DiCaprio.jpg',
#  './Leonardo Dicaprio\\Leonardo-DiCaprio2.jpg',
#  './Leonardo Dicaprio\\Leonardo-DiCaprio3.jpg',
#  './Leonardo Dicaprio\\leonardo-dicaprios.jpg',
#  './Leonardo Dicaprio\\Leonardo2520DiCaprio2C2520Irina2520Shayk.jpg',
#  './Leonardo Dicaprio\\LeonardoDiCaprioNov08.jpg',
#  './Leonardo Dicaprio\\Leonardo_DiCaprio_2014.jpg',
#  './Leonardo Dicaprio\\Leonardo_Dicaprio_Cannes_2019.jpg',
#  './Leonardo Dicaprio\\leonardo_dicaprio_zendaya_getty.jpg',
#  './Matt Damon\\matt-damon-ford.jpg',
#  './Matt Damon\\matt-damon-good-will-hunting.jpg',
#  './Matt Damon\\matt-damon-gq-0816-03.jpg',
#  './Matt Damon\\Matt-Damon-Luciana-Barroso-mc-230728-02-f096db.jpg',
#  './Matt Damon\\matt-damon-luciana-depression-zz-230714-ef925f.jpg',
#  './Matt Damon\\matt-damon-luciana-gettyimages-1185555564.jpg',
#  './Matt Damon\\Matt-Damon-Mark-Wahlberg.jpg',
#  './Matt Damon\\matt-damon-movies-1628080561.jpg',
#  './Matt Damon\\matt-damon-oppenheimer-1689675805608.jpg',
#  './Matt Damon\\matt-damon-oppenheimer-jp-230711-c442c5.jpg',
#  './Matt Damon\\Matt-Damon-Robin-Williams-Good-Will-Hunting.jpg',
#  './Matt Damon\\Matt-Damon-Says-His-Wife-Helped-Him-After-He-Fell-Into-a-Depression.jpg',
#  './Matt Damon\\matt-damon-scarlett-johansson-kiss-quotes.jpg',
#  './Matt Damon\\matt-damon-shirtless.jpg',
#  './Matt Damon\\matt-damon-shows-off-his-fit-physique-day-at-the-beach-09.jpg',
#  './Matt Damon\\Matt-Damon-Through-the-Years-Good-Will-Hunting-and-More-1992.jpg',
#  './Matt Damon\\matt-damon-wife-kids-airport-embed-2.jpg',
#  './Matt Damon\\matt-damon.jpg',
#  './Matt Damon\\matt-damon2.jpg',
#  './Matt Damon\\matt-damon2000x1270-696x442.jpg',
#  './Matt Damon\\matt-damon3.jpg',
#  './Matt Damon\\matt-damon4.jpg',
#  './Matt Damon\\matt-damon5.jpg',
#  './Matt Damon\\MATT-DAMON_WEB-MAIN.jpg',
#  './Matt Damon\\MattDamon.jpg',
#  './Matt Damon\\mattdamongoodwillhunting.jpg',
#  './Matt Damon\\matt_damon.jpg',
#  './Matt Damon\\Matt_Damon_2014_3.jpg',
#  './Matt Damon\\matt_damon_ben_affleck.jpg',
#  './Matt Damon\\maxresdefault.jpg',
#  './Matt Damon\\MIT-NASA-Matt-Damon_0.jpg',
#  './Matt Damon\\MV5BMTM0NzYzNDgxMl5BMl5BanBnXkFtZTcwMDg2MTMyMw._V1_.jpg',
#  './Matt Damon\\MV5BYTQzOGU5OWYtZDFkNy00MzU0LTlkNWYtNTgwZDdjMDhkMWQ3XkEyXkFqcGdeQWFsZWxvZw._V1_.jpg',
#  './Matt Damon\\NINTCHDBPICT000664855940.jpg',
#  './Matt Damon\\oppenheimer-matt-damon.jpg',
#  './Matt Damon\\pitt-damon.jpg',
#  './Matt Damon\\rs-211273-MCDDEPA_EC019_H.jpg',
#  './Matt Damon\\scarlett-johansson-matt-damon-64ba71138ca07.jpg',
#  './Matt Damon\\split_3_16x9_template_v1-copy-1.jpg',
#  './Matt Damon\\the-last-duel-red-carpet---the-78th-venice-international-film-festival.jpg']

# %% [markdown]
# **Removing images which are not good for training using CV2 eyes cascade**

# %%
image = files_names[321]
img = cv2.imread(image)
img_gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    
faces = face_cascade.detectMultiScale(img_gray, 1.3, 5)
print(faces)
for (x,y,w,h) in faces:
    face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    roi_gray = img_gray[y:y+h, x:x+w]
    roi_color = face_img[y:y+h, x:x+w]
    eyes = eye_cascade.detectMultiScale(roi_gray)
    for (ex,ey,ew,eh) in eyes:
        cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)   
plt.imshow(cv2.cvtColor(face_img,cv2.COLOR_BGR2RGB),cmap = 'gray')
# Out:
# [[ 30  54 107 107]]

# %% [markdown]
# **Finding face from the image using face cascade by CV2**

# %%
plt.imshow(cv2.cvtColor(roi_color,cv2.COLOR_BGR2RGB), cmap='gray')

# %%
def cropped_image(image):
    img = cv2.imread(image)
    img_gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    
    faces = face_cascade.detectMultiScale(img_gray, 1.3, 5)
    for (x,y,w,h) in faces:
        face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
        roi_gray = img_gray[y:y+h, x:x+w]
        roi_color = face_img[y:y+h, x:x+w]
        eyes = eye_cascade.detectMultiScale(roi_gray)
        if len(eyes)>=2: # it detected a face
            return roi_color

# %%
crop_img = cropped_image(image)
plt.imshow(crop_img)

# %% [markdown]
# **Wavelet Transforming the image to get more features from face**

# %%
import pywt
def w2d(img, mode='haar', level=1):
    imArray = img
    #convert to grayscale
    imArray = cv2.cvtColor(imArray,cv2.COLOR_RGB2GRAY )
    #convert to float
    imArray =  np.float32(imArray)   
    imArray /= 255;
    # compute coefficients 
    coeffs=pywt.wavedec2(imArray, mode, level=level)

    #Process Coefficients
    coeffs_H=list(coeffs)  
    coeffs_H[0] *= 0;  

    # reconstruction
    imArray_H=pywt.waverec2(coeffs_H, mode);
    imArray_H *= 255;
    imArray_H =  np.uint8(imArray_H)

    return imArray_H

# %% [markdown]
# **We can see how features can be shown by using wavelet transformation like mouth,eyes,nose etc.**

# %%
#wavelet Transformed Image
im_har = w2d(crop_img,'db1',5)
plt.imshow(im_har, cmap='gray')

# %% [markdown]
# **Performing for all the images in the dataset and stacking both color and wavelet image for better accuracies**

# %%
X = []
Y = []
for file in files_names:
    face_image = cropped_image(file)
    if face_image is not None:
        label = file.split('\\')[-2][2:]
        Y.append(labels.index(label))
        im_har = w2d(crop_img,'db1',5)
        scalled_raw_img = cv2.resize(face_image, (32, 32))
        scalled_im_har = cv2.resize(im_har,(32,32))
        combined_image = np.vstack((scalled_raw_img.reshape(-1,1),scalled_im_har.reshape(-1,1)))
        X.append(combined_image)

# %%
X = np.array(X).reshape(len(X),-1).astype(float)
X.shape
# Out:
# (250, 4096)

# %%
 from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size = 0.3,stratify = Y)

# %%
X_train = np.array(X_train,dtype = 'float32')
X_test = np.array(X_test,dtype = 'float32')
Y_test = np.array(Y_test)
Y_train = np.array(Y_train)

# %%
X_train.shape,Y_train.shape,X_test.shape,Y_test.shape
# Out:
# ((175, 4096), (175,), (75, 4096), (75,))

# %%
from sklearn.svm import SVC
from sklearn.metrics import classification_report

# %%
model_svc = SVC()
model_svc.fit(X_train,Y_train)
y_pred = model_svc.predict(X_test)
print(classification_report(Y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.41      0.71      0.52        21
#            1       0.70      0.44      0.54        16
#            2       0.50      0.12      0.19        17
#            3       0.50      0.57      0.53        21
#
#     accuracy                           0.48        75
#    macro avg       0.53      0.46      0.44        75
# weighted avg       0.52      0.48      0.45        75

# %%
from sklearn.naive_bayes import MultinomialNB
model_naive = MultinomialNB()
model_naive.fit(X_train,Y_train)
y_pred = model_naive.predict(X_test)
print(classification_report(Y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.44      0.67      0.53        21
#            1       0.55      0.69      0.61        16
#            2       0.33      0.12      0.17        17
#            3       0.59      0.48      0.53        21
#
#     accuracy                           0.49        75
#    macro avg       0.48      0.49      0.46        75
# weighted avg       0.48      0.49      0.47        75

# %% [markdown]
# **Logistic Regression gave best performance**

# %%
from sklearn.linear_model import LogisticRegression
model_log = LogisticRegression(max_iter = 500)
model_log.fit(X_train,Y_train)
y_pred = model_log.predict(X_test)
print(classification_report(Y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.81      0.81        21
#            1       0.76      0.81      0.79        16
#            2       0.71      0.59      0.65        17
#            3       0.70      0.76      0.73        21
#
#     accuracy                           0.75        75
#    macro avg       0.75      0.74      0.74        75
# weighted avg       0.75      0.75      0.74        75

# %% [markdown]
# **Using standard scaler to improve the accuracy**

# %%
from sklearn.preprocessing import StandardScaler
standard = StandardScaler()
standard = standard.fit(X_train)
sta1 = standard.transform(X_train)
model_log = LogisticRegression(max_iter=200)
model_log.fit(sta1,Y_train)
y_pred = model_log.predict(standard.transform(X_test))
print(classification_report(Y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.81      0.81        21
#            1       0.81      0.81      0.81        16
#            2       0.71      0.71      0.71        17
#            3       0.76      0.76      0.76        21
#
#     accuracy                           0.77        75
#    macro avg       0.77      0.77      0.77        75
# weighted avg       0.77      0.77      0.77        75

# %% [markdown]
# **Downloading image from web**

# %%
import urllib.request
from PIL import Image
  
urllib.request.urlretrieve(
  'https://img.buzzfeed.com/buzzfeed-static/complex/images/o3o899mz6tsznjqrqugu/matt-damon.jpg?downsize=920:*&output-format=auto&output-quality=auto',
   "gfg.png")
  
img = Image.open("gfg.png")
plt.imshow(img)

# %%
import numpy
img = numpy.array(img)
img2 = numpy.array(img)
img_gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
faces = face_cascade.detectMultiScale(img_gray, 1.3, 5)
for (x,y,w,h) in faces:
        face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
        roi_gray = img_gray[y:y+h, x:x+w]
        face_image = face_img[y:y+h, x:x+w]

plt.imshow(face_image)

# %%
im_har = w2d(face_image,'db1',5)
plt.imshow(im_har, cmap='gray')

# %%
scalled_raw_img = cv2.resize(face_image, (32, 32))
scalled_im_har = cv2.resize(im_har,(32,32))
combined_image = np.vstack((scalled_raw_img.reshape(-1,1),scalled_im_har.reshape(-1,1)))
combined_image.shape
# Out:
# (4096, 1)

# %%
X = np.array(combined_image).reshape(1,-1).astype(float)
X.shape
# Out:
# (1, 4096)

# %%
label = model_log.predict(X)[0]
label
# Out:
# 3

# %%
plt.imshow(img)
plt.title(labels[3])
# Out:
# Text(0.5, 1.0, 'Matt Damon')
